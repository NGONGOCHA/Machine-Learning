# %% [markdown]
# <a href="https://colab.research.google.com/github/NGONGOCHA/Machine-Learning/blob/main/Ch%C6%B0%C6%A1ng_1_M%C3%B4_t%E1%BA%A3_to%C3%A1n_h%E1%BB%8Dc_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
cap = cv2.VideoCapture("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở/video2.mp4")

# %%
ret, frame = cap.read()

# %%
print(ret, frame)
# Out:
# True [[[175 180 193]
#   [175 180 193]
#   [176 180 193]
#   ...
#   [111 101 124]
#   [111 101 124]
#   [111 101 124]]
#
#  [[177 182 195]
#   [177 182 195]
#   [178 182 195]
#   ...
#   [111 101 124]
#   [111 101 124]
#   [111 101 124]]
#
#  [[178 182 194]
#   [178 182 194]
#   [178 182 194]
#   ...
#   [110 104 121]
#   [110 104 121]
#   [110 104 121]]
#
#  ...
#
#  [[189  91 121]
#   [189  91 121]
#   [189  91 121]
#   ...
#   [ 86  83 127]
#   [ 86  84 126]
#   [ 86  84 126]]
#
#  [[188  91 123]
#   [188  91 123]
#   [188  91 123]
#   ...
#   [ 89  84 127]
#   [ 90  84 127]
#   [ 90  84 127]]
#
#  [[188  91 123]
#   [188  91 123]
#   [188  91 123]
#   ...
#   [ 89  84 127]
#   [ 92  86 129]
#   [ 92  86 129]]]

# %%
type(frame)
# Out:
# numpy.ndarray

# %%
cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F2616E16490>
