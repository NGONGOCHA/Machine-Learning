# %% [markdown]
# <a href="https://colab.research.google.com/github/NGONGOCHA/Machine-Learning/blob/main/Ch%C6%B0%C6%A1ng_5_B%C3%A0i_t%E1%BA%ADp_t%E1%BA%A1i_l%E1%BB%9Bp_01_Ki%E1%BB%83m_tra_nh%C3%B3m_BTKN_1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bài 4.1: Huấn luyện mô hình Hồi quy tuyến tính

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os
import math
import numpy as np
from sklearn.model_selection import train_test_split

# %%
D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex1data1 (1).txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
print('Kích thước dữ liệu gốc:')
print("\t\tX: ", X.shape, "; y: ", y.shape)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
print('Kích thước dữ liệu train - test:')
print("\t\tX train: ", X_train.shape, "; y train: ",y_train.shape)
print("\t\tX test: ", X_test.shape, "; y test: ",y_test.shape)
# Out:
# Kích thước dữ liệu gốc:
# 		X:  (97, 1) ; y:  (97,)
# Kích thước dữ liệu train - test:
# 		X train:  (67, 1) ; y train:  (67,)
# 		X test:  (30, 1) ; y test:  (30,)

# %%
D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex1data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
print('Kích thước dữ liệu gốc:')
print("\t\tX: ", X.shape, "; y: ", y.shape)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
print('Kích thước dữ liệu train - test:')
print("\t\tX train: ", X_train.shape, "; y train: ",y_train.shape)
print("\t\tX test: ", X_test.shape, "; y test: ",y_test.shape)
# Out:
# Kích thước dữ liệu gốc:
# 		X:  (47, 2) ; y:  (47,)
# Kích thước dữ liệu train - test:
# 		X train:  (32, 2) ; y train:  (32,)
# 		X test:  (15, 2) ; y test:  (15,)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex1data1 (1).txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
m = X.shape[0]
y = np.reshape(y, (m,1))
x0 = np.ones((m,1))
X = np.column_stack([x0, X])
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
mse = (1/m)*np.sum(np.square(y - X))
print(mse)
rmse = math.sqrt(mse)
print(rmse)
# Out:
# 68.35890873767835
# 8.267944650133934

# %%
D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex1data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
m = X.shape[0]
y = np.reshape(y, (m,1))
x0 = np.ones((m,1))
X = np.column_stack([x0, X])
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
mse = (1/m)*np.sum(np.square(y - X))
print(mse)
rmse = math.sqrt(mse)
print(rmse)
# Out:
# 392022569671.68085
# 626117.0574834077

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.linear_model import SGDClassifier

D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex1data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
clf = SGDClassifier(loss="hinge", penalty="l2", max_iter=5)
clf.fit(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# SGDClassifier(max_iter=5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex1data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
y = np.dot(X, np.array([1, 2])) + 3
print(y)
reg = LinearRegression().fit(X, y)
reg.score(X, y)
# Out:
# [2113. 1609. 2409. 1423. 3011. 1996. 1543. 1436. 1389. 1503. 1951. 2009.
#  1899. 4491. 1277. 2311. 1327. 1245. 2620. 3042. 1776. 1895. 1613. 1973.
#  3899. 1109. 1467. 2535. 2209. 2646. 1846. 1005. 2051. 3146. 1822. 1446.
#  1248. 2143. 4226. 2173. 1671. 2247. 2578. 1209.  859. 1863. 1212.]
# 1.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex1data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
scaler = StandardScaler()
print('Kích thước của tập dữ liệu: ', D.shape)
print('Giá trị của tập dữ liệu: ')
print(D)
print('Thực hiện MinMaxScaler')
#Khởi tạo bộ điều chỉnh dữ liệu
scaler = MinMaxScaler()
#Phải thực hiện thao tác fit(data) trước khi điều chỉnh dữ liệu
print(scaler.fit(D))
#Thực hiện điều chỉnh dữ liệu
D = scaler.transform(D)
print('Kích thước của tập dữ liệu: ', D.shape)
print('Giá trị của tập dữ liệu: ')
print(D)
print('Lấy ra tập dữ liệu X, y')
X, y = D[:,:-1], D[:, -1]
print('Kích thước tập X: ', X.shape)
print('Kích thước vector y: ', y.shape)
# Out:
# Kích thước của tập dữ liệu:  (47, 3)
# Giá trị của tập dữ liệu:
# [[2.10400e+03 3.00000e+00 3.99900e+05]
#  [1.60000e+03 3.00000e+00 3.29900e+05]
#  [2.40000e+03 3.00000e+00 3.69000e+05]
#  [1.41600e+03 2.00000e+00 2.32000e+05]
#  [3.00000e+03 4.00000e+00 5.39900e+05]
#  [1.98500e+03 4.00000e+00 2.99900e+05]
#  [1.53400e+03 3.00000e+00 3.14900e+05]
#  [1.42700e+03 3.00000e+00 1.98999e+05]
#  [1.38000e+03 3.00000e+00 2.12000e+05]
#  [1.49400e+03 3.00000e+00 2.42500e+05]
#  [1.94000e+03 4.00000e+00 2.39999e+05]
#  [2.00000e+03 3.00000e+00 3.47000e+05]
#  [1.89000e+03 3.00000e+00 3.29999e+05]
#  [4.47800e+03 5.00000e+00 6.99900e+05]
#  [1.26800e+03 3.00000e+00 2.59900e+05]
#  [2.30000e+03 4.00000e+00 4.49900e+05]
#  [1.32000e+03 2.00000e+00 2.99900e+05]
#  [1.23600e+03 3.00000e+00 1.99900e+05]
#  [2.60900e+03 4.00000e+00 4.99998e+05]
#  [3.03100e+03 4.00000e+00 5.99000e+05]
#  [1.76700e+03 3.00000e+00 2.52900e+05]
#  [1.88800e+03 2.00000e+00 2.55000e+05]
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score

D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex1data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]

print("Thực hiện huấn luyện mô hình với cross_validate;")
cv_results = cross_validate(lasso, X, y, cv=3)
print(cv_results)

print("Thực hiện huấn luyện mô hình với cross_val_score;")
lasso = linear_model.Lasso()
print(cross_val_score(lasso, X, y, cv=3))

print("Sử dụng cross_val_predict để dự đoán")
lasso = linear_model.Lasso()
y_pred = cross_val_predict(lasso, X, y, cv=3)
print(y_pred)
# Out:
# Thực hiện huấn luyện mô hình với cross_validate;
# {'fit_time': array([0.00124907, 0.00096297, 0.00060463]), 'score_time': array([0.00066304, 0.0003643 , 0.00038838]), 'test_score': array([0.84751221, 0.54706604, 0.62530254])}
# Thực hiện huấn luyện mô hình với cross_val_score;
# [0.84751221 0.54706604 0.62530254]
# Sử dụng cross_val_predict để dự đoán
# [355003.82159671 289976.59074315 393194.41749484 276807.33310223
#  460036.94504663 329079.32735543 281461.12003613 267655.7357081
#  261591.68838643 276300.22869855 323273.32460064 341585.50411899
#  327393.05294064 640161.03745841 247141.1926412  369721.3466389
#  271277.42416899 229268.34071173 404459.84241702 467369.00297886
#  308426.5498547  355951.36539914 284127.51390309 308009.06781154
#  624910.31258642 208994.29844535 262362.73323478 421573.5945619
#  372975.52265867 438120.79082342 348646.74722964 253060.67618791
#  360384.60317874 506519.80321264 327978.18499773 265948.13986016
# ...

# %% [markdown]
# #Bài 4.2: Huấn luyện mô hình Hồi quy Logistic

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data1.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
print('Kích thước dữ liệu gốc:')
print("\t\tX: ", X.shape, "; y: ", y.shape)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
print('Kích thước dữ liệu train - test:')
print("\t\tX train: ", X_train.shape, "; y train: ", y_train.shape)
print("\t\tX test: ", X_test.shape, "; y test: ", y_test.shape)
# Out:
# Kích thước dữ liệu gốc:
# 		X:  (100, 2) ; y:  (100,)
# Kích thước dữ liệu train - test:
# 		X train:  (70, 2) ; y train:  (70,)
# 		X test:  (30, 2) ; y test:  (30,)

# %%
D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
print('Kích thước dữ liệu gốc:')
print("\t\tX: ", X.shape, "; y: ", y.shape)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
print('Kích thước dữ liệu train - test:')
print("\t\tX train: ", X_train.shape, "; y train: ", y_train.shape)
print("\t\tX test: ", X_test.shape, "; y test: ", y_test.shape)
# Out:
# Kích thước dữ liệu gốc:
# 		X:  (118, 2) ; y:  (118,)
# Kích thước dữ liệu train - test:
# 		X train:  (82, 2) ; y train:  (82,)
# 		X test:  (36, 2) ; y test:  (36,)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import accuracy_score

D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data1.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
m = X.shape[0]
y = np.reshape(y, (m,1))
x0 = np.ones((m,1))
X = np.column_stack([x0, X])
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
result = (1/m)*np.sum(y_hat == y)
result
# Out:
# 58.800000000000004

# %%
from sklearn.metrics import accuracy_score

D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
m = X.shape[0]
y = np.reshape(y, (m,1))
x0 = np.ones((m,1))
X = np.column_stack([x0, X])
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
result = (1/m)*np.sum(y_hat == y)
result
# Out:
# 59.016949152542374

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.linear_model import SGDClassifier

D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
clf = SGDClassifier(loss="hinge", penalty="l2", max_iter=5)
clf.fit(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# SGDClassifier(max_iter=5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data1.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
m = X.shape[0]
y = np.reshape(y, (m,1))
x0 = np.ones((m,1))
X = np.column_stack([x0, X])
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
mse = (1/m)*np.sum(np.square(y - X))
print(mse)
rmse = math.sqrt(mse)
print(rmse)
# Out:
# 9234.416174770226
# 96.0958697071327

# %%
D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
m = X.shape[0]
y = np.reshape(y, (m,1))
x0 = np.ones((m,1))
X = np.column_stack([x0, X])
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=15)
mse = (1/m)*np.sum(np.square(y - X))
print(mse)
rmse = math.sqrt(mse)
print(rmse)
# Out:
# 1.8403216334676944
# 1.3565845471137044

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data1.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]
scaler = StandardScaler()
print('Kích thước của tập dữ liệu: ', D.shape)
print('Giá trị của tập dữ liệu: ')
print(D)
print('Thực hiện MinMaxScaler')
#Khởi tạo bộ điều chỉnh dữ liệu
scaler = MinMaxScaler()
#Phải thực hiện thao tác fit(data) trước khi điều chỉnh dữ liệu
print(scaler.fit(D))
#Thực hiện điều chỉnh dữ liệu
D = scaler.transform(D)
print('Kích thước của tập dữ liệu: ', D.shape)
print('Giá trị của tập dữ liệu: ')
print(D)
print('Lấy ra tập dữ liệu X, y')
X, y = D[:,:-1], D[:, -1]
print('Kích thước tập X: ', X.shape)
print('Kích thước vector y: ', y.shape)
# Out:
# Kích thước của tập dữ liệu:  (100, 3)
# Giá trị của tập dữ liệu:
# [[34.62365962 78.02469282  0.        ]
#  [30.28671077 43.89499752  0.        ]
#  [35.84740877 72.90219803  0.        ]
#  [60.18259939 86.3085521   1.        ]
#  [79.03273605 75.34437644  1.        ]
#  [45.08327748 56.31637178  0.        ]
#  [61.10666454 96.51142588  1.        ]
#  [75.02474557 46.55401354  1.        ]
#  [76.0987867  87.42056972  1.        ]
#  [84.43281996 43.53339331  1.        ]
#  [95.86155507 38.22527806  0.        ]
#  [75.01365839 30.60326323  0.        ]
#  [82.30705337 76.4819633   1.        ]
#  [69.36458876 97.71869196  1.        ]
#  [39.53833914 76.03681085  0.        ]
#  [53.97105215 89.20735014  1.        ]
#  [69.07014406 52.74046973  1.        ]
#  [67.94685548 46.67857411  0.        ]
#  [70.66150955 92.92713789  1.        ]
#  [76.97878373 47.57596365  1.        ]
#  [67.37202755 42.83843832  0.        ]
#  [89.67677575 65.79936593  1.        ]
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score

D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data1.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]

print("Thực hiện huấn luyện mô hình với cross_validate;")
cv_results = cross_validate(lasso, X, y, cv=3)
print(cv_results)

print("Thực hiện huấn luyện mô hình với cross_val_score;")
lasso = linear_model.Lasso()
print(cross_val_score(lasso, X, y, cv=3))

print("Sử dụng cross_val_predict để dự đoán")
lasso = linear_model.Lasso()
y_pred = cross_val_predict(lasso, X, y, cv=3)
print(y_pred)
# Out:
# Thực hiện huấn luyện mô hình với cross_validate;
# {'fit_time': array([0.00101829, 0.00076771, 0.00060582]), 'score_time': array([0.00082088, 0.00037503, 0.00034475]), 'test_score': array([0.50242446, 0.54347798, 0.36484729])}
# Thực hiện huấn luyện mô hình với cross_val_score;
# [0.50242446 0.54347798 0.36484729]
# Sử dụng cross_val_predict để dự đoán
# [ 0.3416013  -0.06917999  0.30275196  0.73941074  0.85369697  0.241114
#   0.85768087  0.50292753  0.94468779  0.58568502  0.66902666  0.33546736
#   0.90546071  0.97079845  0.38053261  0.69425935  0.49538968  0.41813546
#   0.93631081  0.53741773  0.3708595   0.88304767  0.22916652 -0.01813075
#   0.77336768  0.59325874  0.54758935  0.6416448   0.38125848  0.25555563
#   0.61234422  0.73931688  0.39801659  0.46339809  0.46146346  0.3945393
#   0.70298666  0.80177799  0.47480312  0.44692487  0.72505158  0.30575566
#   0.92932078  0.53833597  0.2895612   0.46693274  0.81444878  1.19342091
# ...

# %%
D = np.loadtxt(os.path.join("/content/drive/MyDrive/Classroom/Học máy 1 Phần cơ sở", "ex2data2.txt"), delimiter=",")
X, y = D[:,:-1], D[:,-1]

print("Thực hiện huấn luyện mô hình với cross_validate;")
cv_results = cross_validate(lasso, X, y, cv=3)
print(cv_results)

print("Thực hiện huấn luyện mô hình với cross_val_score;")
lasso = linear_model.Lasso()
print(cross_val_score(lasso, X, y, cv=3))

print("Sử dụng cross_val_predict để dự đoán")
lasso = linear_model.Lasso()
y_pred = cross_val_predict(lasso, X, y, cv=3)
print(y_pred)
# Out:
# Thực hiện huấn luyện mô hình với cross_validate;
# {'fit_time': array([0.00107884, 0.00132418, 0.00093198]), 'score_time': array([0.00066209, 0.00096011, 0.0004921 ]), 'test_score': array([ 0.        , -0.00807258,  0.        ])}
# Thực hiện huấn luyện mô hình với cross_val_score;
# [ 0.         -0.00807258  0.        ]
# Sử dụng cross_val_predict để dự đoán
# [0.23076923 0.23076923 0.23076923 0.23076923 0.23076923 0.23076923
#  0.23076923 0.23076923 0.23076923 0.23076923 0.23076923 0.23076923
#  0.23076923 0.23076923 0.23076923 0.23076923 0.23076923 0.23076923
#  0.23076923 0.23076923 0.23076923 0.23076923 0.23076923 0.23076923
#  0.23076923 0.23076923 0.23076923 0.23076923 0.23076923 0.23076923
#  0.23076923 0.23076923 0.23076923 0.23076923 0.23076923 0.23076923
#  0.23076923 0.23076923 0.23076923 0.23076923 0.50632911 0.50632911
#  0.50632911 0.50632911 0.50632911 0.50632911 0.50632911 0.50632911
#  0.50632911 0.50632911 0.50632911 0.50632911 0.50632911 0.50632911
# ...
