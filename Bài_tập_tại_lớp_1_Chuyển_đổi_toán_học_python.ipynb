# %% [markdown]
# <a href="https://colab.research.google.com/github/NGONGOCHA/Machine-Learning/blob/main/B%C3%A0i_t%E1%BA%ADp_t%E1%BA%A1i_l%E1%BB%9Bp_1_Chuy%E1%BB%83n_%C4%91%E1%BB%95i_to%C3%A1n_h%E1%BB%8Dc_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
v = [ 1, 2, 3, 4, 5] 
v = np.array(v) 
print(v)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
w = ([[1], [2], [3], [4], [5]]) 
w = np.array(w) 
print(w)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("số chiều của vector v là: ", v.ndim)
print("số chiều của vector w là: ", w.ndim)

print("kích thước của vector v là: ", v.shape)
print("kích thước của vector w là: ", w.shape)
# Out:
# số chiều của vector v là:  1
# số chiều của vector w là:  2
# kích thước của vector v là:  (5,)
# kích thước của vector w là:  (5, 1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#cách 1
u = ([[6], [7], [8], [9], [10]])
w = ([[1], [2], [3], [4], [5]])
X1 = np.column_stack((u,w))
print(X1)
# Out:
# [[ 6  1]
#  [ 7  2]
#  [ 8  3]
#  [ 9  4]
#  [10  5]]

# %%
#cách 2
X2 = np.hstack((u,w))
print(X2)
# Out:
# [[ 6  1]
#  [ 7  2]
#  [ 8  3]
#  [ 9  4]
#  [10  5]]

# %%
print("số chiều của ma trận X là: ", X1.ndim)

print("kích thước của ma trận X là: ", X2.shape)
# Out:
# số chiều của ma trận X là:  2
# kích thước của ma trận X là:  (5, 2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
X = [[1,2,3,4,5],
     [6,7,8,9,2],
     [4,5,7,2,1]] 
X = np.array(X) 
print(X)
# Out:
# [[1 2 3 4 5]
#  [6 7 8 9 2]
#  [4 5 7 2 1]]

# %%
print(np.reshape(X, (3, 5)))
# Out:
# [[1 2 3 4 5]
#  [6 7 8 9 2]
#  [4 5 7 2 1]]

# %%
print("số chiều của ma trận X là: ", X.ndim)

print("kích thước của ma trận X là: ", X.shape)
# Out:
# số chiều của ma trận X là:  2
# kích thước của ma trận X là:  (3, 5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("ma trận X:\n", X)
print("vector v:\n", v) 

Xv = np.dot(X,v)
print("nhân ma trận X với vector v: \n", Xv)

print("số chiều là: ", Xv.ndim)
print("kích thước là: ", Xv.shape)
# Out:
# ma trận X:
#  [[1 2 3 4 5]
#  [6 7 8 9 2]
#  [4 5 7 2 1]]
# vector v:
#  [1 2 3 4 5]
# nhân ma trận X với vector v:
#  [55 90 48]
# số chiều là:  1
# kích thước là:  (3,)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("ma trận X:\n", X)
print("vector w:\n", w) 

Xw = np.dot(X,w)
print("nhân ma trận X với vector w: \n", Xw)

print("số chiều là: ", Xw.ndim)
print("kích thước là: ", Xw.shape)
# Out:
# ma trận X:
#  [[1 2 3 4 5]
#  [6 7 8 9 2]
#  [4 5 7 2 1]]
# vector w:
#  [[1], [2], [3], [4], [5]]
# nhân ma trận X với vector w:
#  [[55]
#  [90]
#  [48]]
# số chiều là:  2
# kích thước là:  (3, 1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("ma trận X:\n", X)
print("ma trận chuyển vị của X là: \n", X.T)
# Out:
# ma trận X:
#  [[1 2 3 4 5]
#  [6 7 8 9 2]
#  [4 5 7 2 1]]
# ma trận chuyển vị của X là:
#  [[1 6 4]
#  [2 7 5]
#  [3 8 7]
#  [4 9 2]
#  [5 2 1]]
